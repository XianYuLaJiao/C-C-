# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import re
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import TensorBoard
from keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout,GRU
from keras.optimizers import SGD# 随机梯度下降法
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### 第2步：加载历史数据文件

# %%
dataset = pd.read_csv(r'D:\资料\IBM历史数据19801124-20000905.csv', index_col='date', parse_dates=(['date']))

# %%
def date001(x):
    date002 = re.match(r'(\d{4}).?(\d*).?(\d*)',x)
    nian = date002.group(1)
    yue = date002.group(2)
    ri =date002.group(3)
    date003 = nian + '-' + yue + '-' +ri
    return date003
da = pd.DataFrame(dataset.index)
dataset.index = da['date'].apply(lambda x: date001(x))
print(dataset.head())
# Out:
#                收盘      开盘       高       低    交易量     涨跌幅
# date
# 2000-9-5   131.19  132.81  133.31  130.81  4.11M  -1.82%
# 2000-9-1   133.62  133.06  134.94  132.62  5.78M   1.21%
# 2000-8-31  132.02  131.88  134.19  131.62  5.47M   1.31%
# 2000-8-30  130.31  130.75  131.50  129.56  4.93M  -1.93%
# 2000-8-29  132.88  131.50  134.25  131.00  6.04M   1.05%

# %%
dataset.shape
# Out:
# (5000, 6)

# %%
#检查数据是否有缺失值
train_set = dataset[:'1986-10-10':-1].iloc[:,0:1]
test_set = dataset['1986-10-10':'1988-10-10':-1].iloc[:,0:1]

# %%
train_set.shape
# Out:
# (1487, 1)

# %%
test_set.shape
# Out:
# (506, 1)

# %% [markdown]
# #### 定义显示函数

# %%
def plot_predictions(test_result, predict_result):
    """
    :param test_result: 真实值测试结果
    :param predict_result: 预测值结果
    :return:
    """
    fig = plt.figure(figsize=[15, 7], dpi=200)
    ax = fig.add_axes([0.05, 0.05, 0.9, 0.9])
    ax.set_xlabel('time', fontsize='10')
    ax.set_ylabel('stock price', fontsize='10')
    ax.plot(test_result, color='r', label='IBM True Stock Price')
    ax.plot(predict_result, color='b', label='IBM Predicted Stock Price')
    plt.legend()
    plt.show()

# %%
dataset['开盘'][:'1986-10-10':-1].plot(figsize=[25,8], legend=True,color='b')
dataset['开盘']['1986-10-10':'1988-10-10':-1].plot(figsize=[25,8], legend=True,color='g')
plt.title('IBM Stock Price')
plt.legend(["1990","1980"])
plt.show()

# %%
# 归一化：将每一维的特征映射到指定区间：【0，1】
sc = MinMaxScaler(feature_range=[0,1])# 最大最小值归一化
train_set_scaled = sc.fit_transform(train_set)
print(train_set_scaled.shape)
train_set_scaled
# Out:
# (1487, 1)
# array([[0.19010324],
#        [0.18262727],
#        [0.1758633 ],
#        ...,
#        [0.6988252 ],
#        [0.6496974 ],
#        [0.66429334]])

# %%
# 创建序列数据集（训练和测试）
# 60个时间步为一个样本，1输出
x_train = []
y_train = []
for i in range(60, 1487):
    x_train.append(train_set_scaled[i-60:i,0])
    y_train.append(train_set_scaled[i,0])
         
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2132a220a582> in <module>
# ----> 1 x_train.shape
#
# NameError: name 'x_train' is not defined

# %%
print(y_train)
x_train[0:2]
# Out:
# [0.10217159 0.11569954 0.11676753 ... 0.6988252  0.6496974  0.66429334]
# array([[[0.19010324],
#         [0.18262727],
#         [0.1758633 ],
#         [0.17016732],
#         [0.15557138],
#         [0.16803133],
#         [0.16909932],
#         [0.17230331],
#         [0.16482734],
#         [0.15450338],
#         [0.15236739],
#         [0.13136347],
#         [0.13777145],
#         [0.1491634 ],
#         [0.13777145],
#         [0.15343539],
#         [0.14453542],
#         [0.13029548],
#         [0.13919544],
#         [0.16126735],
#         [0.16233535],
#         [0.17337131],
#         [0.17799929],
#         [0.16909932],
#         [0.1747953 ],
#         [0.16803133],
#         [0.17906728],
#         [0.18903524],
#         [0.2004272 ],
#         [0.18262727],
#         [0.16589534],
#         [0.16340335],
#         [0.15806337],
#         [0.15557138],
#         [0.15806337],
#         [0.1491634 ],
#         [0.15913136],
#         [0.15699537],
#         [0.14239943],
#         [0.14346743],
#         [0.14453542],
#         [0.14239943],
#         [0.14239943],
#         [0.14702741],
#         [0.13919544],
#         [0.14133143],
#         [0.13670345],
#         [0.12780349],
#         [0.13563546],
#         [0.13777145],
#         [0.13349947],
#         [0.13563546],
#         [0.12922748],
#         [0.1245995 ],
#         [0.12139551],
#         [0.11356355],
#         [0.11356355],
#         [0.11569954],
#         [0.11569954],
#         [0.10893556]],
#
#        [[0.18262727],
#         [0.1758633 ],
#         [0.17016732],
#         [0.15557138],
#         [0.16803133],
#         [0.16909932],
#         [0.17230331],
#         [0.16482734],
#         [0.15450338],
#         [0.15236739],
#         [0.13136347],
#         [0.13777145],
#         [0.1491634 ],
#         [0.13777145],
#         [0.15343539],
#         [0.14453542],
#         [0.13029548],
#         [0.13919544],
#         [0.16126735],
#         [0.16233535],
#         [0.17337131],
#         [0.17799929],
#         [0.16909932],
#         [0.1747953 ],
#         [0.16803133],
#         [0.17906728],
#         [0.18903524],
#         [0.2004272 ],
#         [0.18262727],
#         [0.16589534],
#         [0.16340335],
#         [0.15806337],
#         [0.15557138],
#         [0.15806337],
#         [0.1491634 ],
#         [0.15913136],
#         [0.15699537],
#         [0.14239943],
#         [0.14346743],
#         [0.14453542],
#         [0.14239943],
#         [0.14239943],
#         [0.14702741],
#         [0.13919544],
#         [0.14133143],
#         [0.13670345],
#         [0.12780349],
#         [0.13563546],
#         [0.13777145],
#         [0.13349947],
#         [0.13563546],
#         [0.12922748],
#         [0.1245995 ],
#         [0.12139551],
#         [0.11356355],
#         [0.11356355],
#         [0.11569954],
#         [0.11569954],
#         [0.10893556],
#         [0.10217159]]])

# %%
# LSTM输入:(samples, sequence_length, features)
# 将训练集重构，转换成LSTM网络可以识别的数据reshape:训练集(2700,60) --->(2700 , 60 , 1)
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))

# %%
x_train
# Out:
# array([[[0.19010324],
#         [0.18262727],
#         [0.1758633 ],
#         ...,
#         [0.11569954],
#         [0.11569954],
#         [0.10893556]],
#
#        [[0.18262727],
#         [0.1758633 ],
#         [0.17016732],
#         ...,
#         [0.11569954],
#         [0.10893556],
#         [0.10217159]],
#
#        [[0.1758633 ],
#         [0.17016732],
#         [0.15557138],
#         ...,
#         [0.10893556],
#         [0.10217159],
#         [0.11569954]],
#
#        ...,
#
#        [[0.77216091],
#         [0.74866501],
#         [0.73869705],
#         ...,
#         [0.72872909],
#         [0.75222499],
#         [0.70416518]],
#
#        [[0.74866501],
#         [0.73869705],
#         [0.73656105],
#         ...,
#         [0.75222499],
#         [0.70416518],
#         [0.6988252 ]],
#
#        [[0.73869705],
#         [0.73656105],
#         [0.73762905],
#         ...,
#         [0.70416518],
#         [0.6988252 ],
#         [0.6496974 ]]])

# %% [markdown]
# #### 搭建模型

# %%
model = Sequential()
#LSTM 第一层
model.add(LSTM(128,return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))

# 第二层
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))

#第三层
model.add(LSTM(128))
model.add(Dropout(0.2))

# Dense层
model.add(Dense(units=1))
y_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e996895d6698> in <module>
# ----> 1 model = Sequential()
#       2 #LSTM 第一层
#       3 model.add(LSTM(128,return_sequences=True, input_shape=(x_train.shape[1], 1)))
#       4 model.add(Dropout(0.2))
#       5
#
# NameError: name 'Sequential' is not defined

# %%
# 模型编译
model.compile(optimizer='adadelta',loss='mse')

# 训练模型
model.fit(x_train, y_train, epochs=40, batch_size=72)
# Out:
# Epoch 1/40
# 1427/1427 [==============================] - 3s 2ms/step - loss: 0.0359
# Epoch 2/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0095
# Epoch 3/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0104
# Epoch 4/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0074
# Epoch 5/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0089
# Epoch 6/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0097
# Epoch 7/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0055
# Epoch 8/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0086
# Epoch 9/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0068
# Epoch 10/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0064
# Epoch 11/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0079
# Epoch 12/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0072
# Epoch 13/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0044
# Epoch 14/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0057
# Epoch 15/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0050
# Epoch 16/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0062
# Epoch 17/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0031
# Epoch 18/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0046
# Epoch 19/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0049
# Epoch 20/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0064
# Epoch 21/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0038
# Epoch 22/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0024
# Epoch 23/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0038
# Epoch 24/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0055
# Epoch 25/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0027
# Epoch 26/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0038
# Epoch 27/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0033
# Epoch 28/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0039
# Epoch 29/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0025
# Epoch 30/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0031
# Epoch 31/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0046
# Epoch 32/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0033
# Epoch 33/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0045
# Epoch 34/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0046
# Epoch 35/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0029
# Epoch 36/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0018
# Epoch 37/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0025
# Epoch 38/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0029
# Epoch 39/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0030
# Epoch 40/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0041

# %% [markdown]
# #### 构建数据集进行预测

# %%
dataset_total = pd.concat((dataset['开盘'][:'1986-10-10':-1],dataset['开盘']['1986-10-10':'1988-10-10':-1]),axis=0)
# 获取输入数据
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values

# %%
inputs
# Out:
# array([32.94, 32.97, 33.41, 33.28, 33.28, 33.53, 33.09, 32.81, 33.06,
#        33.12, 32.84, 32.91, 32.72, 32.78, 32.75, 32.5 , 32.75, 33.12,
#        33.5 , 33.56, 33.28, 33.84, 34.19, 34.81, 34.5 , 34.5 , 34.75,
#        35.28, 35.28, 35.  , 34.69, 34.  , 34.03, 34.84, 35.09, 35.94,
#        35.97, 36.03, 34.81, 34.34, 34.25, 34.56, 34.41, 34.59, 34.22,
#        34.66, 34.81, 34.38, 33.94, 33.88, 33.56, 33.62, 33.25, 33.25,
#        32.72, 33.38, 32.03, 31.88, 30.5 , 30.91, 30.91, 30.5 , 30.22,
#        30.75, 30.28, 30.47, 30.06, 30.34, 30.09, 30.38, 30.34, 30.53,
#        30.19, 30.22, 30.5 , 30.91, 31.59, 31.47, 30.78, 30.34, 30.38,
#        30.78, 30.94, 30.69, 29.97, 30.34, 30.5 , 30.12, 30.75, 30.88,
#        30.81, 31.16, 31.78, 31.5 , 31.78, 31.84, 32.47, 32.16, 31.94,
#        31.66, 31.94, 31.72, 32.  , 32.  , 31.62, 31.91, 32.03, 31.69,
#        31.34, 31.28, 30.78, 30.12, 30.5 , 30.5 , 30.16, 30.22, 30.  ,
#        30.5 , 30.91, 30.75, 30.88, 30.72, 30.56, 30.09, 29.12, 29.66,
#        30.  , 30.  , 31.31, 30.69, 30.69, 31.84, 31.56, 31.81, 32.34,
#        32.5 , 32.16, 32.19, 33.06, 33.25, 33.78, 34.22, 33.94, 33.44,
#        33.34, 33.5 , 33.16, 33.62, 34.59, 34.5 , 34.78, 34.91, 35.84,
#        35.75, 35.44, 34.84, 34.88, 34.62, 34.53, 34.97, 35.09, 34.84,
#        34.72, 35.72, 35.44, 36.06, 36.22, 36.16, 36.78, 36.56, 36.75,
#        37.16, 37.44, 38.22, 38.91, 38.5 , 37.69, 38.09, 37.53, 37.78,
#        37.  , 37.38, 37.34, 36.62, 36.91, 36.  , 36.25, 36.91, 37.03,
#        37.72, 37.5 , 37.5 , 39.25, 38.56, 38.56, 37.94, 38.56, 38.81,
#        39.66, 40.03, 40.16, 40.75, 41.72, 41.69, 41.22, 40.94, 40.75,
#        41.34, 41.56, 41.28, 40.16, 40.25, 39.19, 39.16, 39.31, 39.16,
#        40.16, 40.25, 40.66, 40.  , 39.91, 39.31, 40.06, 40.34, 40.  ,
#        40.31, 39.97, 39.44, 39.41, 39.16, 39.91, 40.5 , 40.34, 40.22,
#        40.34, 40.81, 41.22, 41.53, 41.97, 41.62, 41.34, 40.62, 41.  ,
#        41.06, 41.28, 40.97, 41.69, 41.56, 41.75, 42.47, 41.88, 42.  ,
#        42.03, 41.75, 41.16, 40.69, 40.34, 40.03, 40.31, 40.53, 40.31,
#        40.38, 40.59, 40.25, 39.81, 39.84, 40.06, 40.75, 41.09, 41.69,
#        42.25, 42.59, 43.34, 43.31, 43.62, 43.22, 43.16, 43.69, 43.69,
#        43.66, 43.  , 41.97, 41.56, 41.62, 42.09, 40.72, 40.62, 40.41,
#        40.19, 39.44, 39.31, 39.44, 40.28, 40.62, 39.38, 39.16, 39.47,
#        38.84, 37.62, 38.94, 38.56, 38.97, 39.  , 38.19, 37.62, 37.69,
#        38.66, 38.81, 39.12, 37.75, 38.19, 37.88, 36.84, 37.38, 37.19,
#        36.31, 35.03, 33.75, 26.  , 28.75, 30.69, 30.  , 30.19, 28.  ,
#        29.5 , 29.5 , 30.06, 30.62, 31.12, 30.47, 30.16, 30.94, 29.88,
#        29.53, 29.44, 29.81, 30.56, 30.41, 30.  , 29.44, 29.59, 28.91,
#        29.44, 29.38, 29.62, 29.41, 28.72, 27.69, 27.81, 27.62, 26.62,
#        26.94, 27.38, 27.88, 28.5 , 27.75, 27.53, 28.78, 29.  , 29.72,
#        28.88, 29.31, 29.56, 29.56, 29.88, 29.97, 28.94, 29.  , 29.25,
#        28.88, 30.19, 30.47, 30.72, 30.84, 28.72, 29.44, 28.81, 29.03,
#        28.97, 29.75, 29.44, 27.94, 27.59, 27.75, 27.62, 28.31, 27.97,
#        28.19, 28.44, 28.09, 27.5 , 27.47, 27.25, 27.16, 27.  , 26.94,
#        27.28, 27.91, 27.81, 28.  , 28.44, 28.19, 28.12, 28.34, 28.81,
#        28.84, 29.03, 28.62, 28.94, 29.38, 29.25, 29.31, 29.12, 29.22,
#        29.31, 29.41, 29.16, 28.44, 28.88, 28.88, 28.5 , 28.81, 28.72,
#        28.56, 28.44, 28.28, 27.91, 27.5 , 26.75, 27.03, 26.47, 26.28,
#        26.91, 26.88, 26.88, 27.41, 27.31, 27.91, 28.34, 28.41, 29.03,
#        27.84, 28.53, 28.5 , 28.28, 28.22, 28.09, 28.44, 28.47, 28.56,
#        28.5 , 28.28, 28.34, 28.53, 28.66, 28.31, 27.81, 27.62, 27.62,
#        27.72, 27.19, 27.19, 27.59, 27.91, 27.53, 27.22, 27.62, 27.38,
#        27.19, 27.31, 27.12, 27.06, 27.  , 28.12, 28.28, 28.16, 28.31,
#        28.59, 28.44, 29.16, 28.84, 29.  , 29.25, 29.69, 29.72, 29.28,
#        29.38, 29.28, 30.06, 30.75, 31.44, 31.28, 31.25, 31.75, 31.75,
#        31.84, 31.66, 32.31, 31.72, 31.91, 31.59, 31.69, 31.31, 31.31,
#        31.19, 31.38, 31.28, 31.  , 31.  , 30.44, 30.03, 30.59, 30.66,
#        30.28, 30.94, 31.44, 31.56, 31.44, 31.44, 31.06, 30.97, 30.78,
#        30.41, 29.72, 29.75, 29.5 , 28.78, 28.94, 28.66, 28.66, 28.19,
#        27.69, 27.72, 28.19, 27.91, 28.06, 28.34, 28.22, 27.88, 27.56,
#        28.5 , 28.22, 27.94, 28.03, 28.59, 28.41, 28.75, 28.66, 28.44,
#        28.56, 28.19, 28.19, 28.31, 28.  , 28.22, 28.06, 28.31, 28.47,
#        28.84, 28.84, 28.72, 28.62, 28.47, 28.5 , 29.  , 29.03])

# %%
# 归一化
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

# %%
inputs.shape
# Out:
# (566, 1)

# %%
# 准备测试集进行预测
x_test = []
for i in range(60 , 566):
    x_test.append(inputs[i-60:i,0])
    
x_test=np.array(x_test)
x_test.shape
# Out:
# (506, 60)

# %%
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape
# Out:
# (506, 60, 1)

# %%
predict_test = model.predict(x_test) # 预测

# %%
predict_test.shape
# Out:
# (506, 1)

# %%
predict_stock_price = sc.inverse_transform(predict_test)

# %%
predict_stock_price
# Out:
# array([[30.948477],
#        [30.685354],
#        [30.4144  ],
#        [30.141062],
#        [29.888262],
#        [29.657152],
#        [29.455147],
#        [29.275534],
#        [29.123173],
#        [28.993168],
#        [28.890015],
#        [28.812479],
#        [28.762098],
#        [28.727669],
#        [28.703405],
#        [28.692562],
#        [28.704235],
#        [28.754103],
#        [28.837158],
#        [28.92628 ],
#        [28.996273],
#        [29.039522],
#        [29.066408],
#        [29.087317],
#        [29.101   ],
#        [29.090542],
#        [29.062788],
#        [29.028345],
#        [28.984509],
#        [28.948381],
#        [28.929583],
#        [28.92762 ],
#        [28.94767 ],
#        [29.002138],
#        [29.081364],
#        [29.181376],
#        [29.29536 ],
#        [29.429962],
#        [29.572813],
#        [29.708132],
#        [29.820463],
#        [29.911455],
#        [29.977942],
#        [30.0281  ],
#        [30.066887],
#        [30.088224],
#        [30.099255],
#        [30.107334],
#        [30.107578],
#        [30.091043],
#        [30.056208],
#        [29.994778],
#        [29.894129],
#        [29.768316],
#        [29.631145],
#        [29.485903],
#        [29.340872],
#        [29.19802 ],
#        [29.073761],
#        [28.984629],
#        [28.929415],
#        [28.906008],
#        [28.90441 ],
#        [28.912712],
#        [28.912664],
#        [28.874983],
#        [28.808891],
#        [28.733452],
#        [28.660269],
#        [28.627422],
#        [28.628767],
#        [28.655457],
#        [28.726242],
#        [28.831745],
#        [28.96485 ],
#        [29.126598],
#        [29.311424],
#        [29.49945 ],
#        [29.677567],
#        [29.858263],
#        [30.045626],
#        [30.247557],
#        [30.469374],
#        [30.69658 ],
#        [30.904034],
#        [31.077095],
#        [31.215256],
#        [31.312859],
#        [31.383448],
#        [31.45862 ],
#        [31.545984],
#        [31.650515],
#        [31.771101],
#        [31.9229  ],
#        [32.099674],
#        [32.281906],
#        [32.441414],
#        [32.567566],
#        [32.65265 ],
#        [32.69674 ],
#        [32.71669 ],
#        [32.726067],
#        [32.72614 ],
#        [32.7163  ],
#        [32.721996],
#        [32.743748],
#        [32.792755],
#        [32.87076 ],
#        [32.96938 ],
#        [33.09316 ],
#        [33.230515],
#        [33.37483 ],
#        [33.527668],
#        [33.690304],
#        [33.87502 ],
#        [34.093414],
#        [34.328014],
#        [34.543312],
#        [34.731945],
#        [34.877644],
#        [34.98368 ],
#        [35.03775 ],
#        [35.05198 ],
#        [35.03735 ],
#        [34.98736 ],
#        [34.914127],
#        [34.80769 ],
#        [34.679028],
#        [34.555622],
#        [34.453766],
#        [34.39491 ],
#        [34.37607 ],
#        [34.389057],
#        [34.46492 ],
#        [34.586   ],
#        [34.73331 ],
#        [34.875755],
#        [35.01216 ],
#        [35.145126],
#        [35.29226 ],
#        [35.46229 ],
#        [35.65256 ],
#        [35.86631 ],
#        [36.116467],
#        [36.39338 ],
#        [36.669487],
#        [36.919735],
#        [37.12761 ],
#        [37.30204 ],
#        [37.452934],
#        [37.57808 ],
#        [37.652542],
#        [37.675865],
#        [37.63271 ],
#        [37.529934],
#        [37.38771 ],
#        [37.22205 ],
#        [37.071236],
#        [36.954056],
#        [36.88435 ],
#        [36.845528],
#        [36.82415 ],
#        [36.798397],
#        [36.778214],
#        [36.773476],
#        [36.777622],
#        [36.793346],
#        [36.811348],
#        [36.81488 ],
#        [36.799194],
#        [36.76075 ],
#        [36.72066 ],
#        [36.70231 ],
#        [36.707836],
#        [36.7307  ],
#        [36.767097],
#        [36.822624],
#        [36.903656],
#        [37.012653],
#        [37.152195],
#        [37.305588],
#        [37.452866],
#        [37.566742],
#        [37.648052],
#        [37.702335],
#        [37.740376],
#        [37.761456],
#        [37.784214],
#        [37.812138],
#        [37.849133],
#        [37.910233],
#        [37.981747],
#        [38.05694 ],
#        [38.130913],
#        [38.193527],
#        [38.227825],
#        [38.22083 ],
#        [38.167408],
#        [38.06874 ],
#        [37.94292 ],
#        [37.8108  ],
#        [37.680645],
#        [37.56064 ],
#        [37.46027 ],
#        [37.374714],
#        [37.29162 ],
#        [37.208607],
#        [37.13204 ],
#        [37.08114 ],
#        [37.06795 ],
#        [37.104218],
#        [37.19692 ],
#        [37.343204],
#        [37.5445  ],
#        [37.78441 ],
#        [38.049187],
#        [38.312054],
#        [38.553936],
#        [38.77622 ],
#        [38.97682 ],
#        [39.152702],
#        [39.28766 ],
#        [39.35624 ],
#        [39.34978 ],
#        [39.28045 ],
#        [39.177395],
#        [39.030766],
#        [38.846684],
#        [38.634968],
#        [38.405655],
#        [38.15547 ],
#        [37.89101 ],
#        [37.6279  ],
#        [37.39866 ],
#        [37.224136],
#        [37.079044],
#        [36.946796],
#        [36.829082],
#        [36.71276 ],
#        [36.56763 ],
#        [36.421394],
#        [36.280727],
#        [36.160748],
#        [36.06773 ],
#        [35.98313 ],
#        [35.887203],
#        [35.778446],
#        [35.684128],
#        [35.618614],
#        [35.59132 ],
#        [35.567997],
#        [35.545017],
#        [35.514317],
#        [35.45096 ],
#        [35.365356],
#        [35.263855],
#        [35.134445],
#        [34.951385],
#        [34.689495],
#        [34.178688],
#        [33.47371 ],
#        [32.697327],
#        [31.917484],
#        [31.188437],
#        [30.490234],
#        [29.864119],
#        [29.330706],
#        [28.909504],
#        [28.612919],
#        [28.443306],
#        [28.367088],
#        [28.348001],
#        [28.380232],
#        [28.425459],
#        [28.456165],
#        [28.460978],
#        [28.44904 ],
#        [28.445805],
#        [28.456543],
#        [28.470665],
#        [28.469328],
#        [28.451443],
#        [28.403643],
#        [28.34024 ],
#        [28.270235],
#        [28.206287],
#        [28.149078],
#        [28.08247 ],
#        [27.978424],
#        [27.8382  ],
#        [27.668169],
#        [27.45672 ],
#        [27.220331],
#        [26.98749 ],
#        [26.787766],
#        [26.647753],
#        [26.552761],
#        [26.485714],
#        [26.466887],
#        [26.501516],
#        [26.598532],
#        [26.726818],
#        [26.874947],
#        [27.0366  ],
#        [27.202291],
#        [27.370684],
#        [27.538305],
#        [27.674246],
#        [27.769594],
#        [27.831694],
#        [27.859001],
#        [27.888456],
#        [27.940613],
#        [28.02423 ],
#        [28.13757 ],
#        [28.219809],
#        [28.267221],
#        [28.268068],
#        [28.231548],
#        [28.167854],
#        [28.106867],
#        [28.054354],
#        [27.976086],
#        [27.856506],
#        [27.703997],
#        [27.529037],
#        [27.361652],
#        [27.208956],
#        [27.080702],
#        [26.985943],
#        [26.916218],
#        [26.850956],
#        [26.782003],
#        [26.703234],
#        [26.613941],
#        [26.514336],
#        [26.40769 ],
#        [26.307905],
#        [26.23757 ],
#        [26.199957],
#        [26.19606 ],
#        [26.230938],
#        [26.292398],
#        [26.367184],
#        [26.450766],
#        [26.548883],
#        [26.659248],
#        [26.780289],
#        [26.896059],
#        [27.005701],
#        [27.11771 ],
#        [27.228851],
#        [27.336386],
#        [27.432268],
#        [27.515179],
#        [27.586884],
#        [27.650616],
#        [27.701324],
#        [27.720446],
#        [27.716452],
#        [27.69713 ],
#        [27.659767],
#        [27.615156],
#        [27.56803 ],
#        [27.518162],
#        [27.464386],
#        [27.404512],
#        [27.331371],
#        [27.236492],
#        [27.104715],
#        [26.947094],
#        [26.76349 ],
#        [26.559006],
#        [26.360554],
#        [26.182688],
#        [26.032423],
#        [25.924639],
#        [25.858057],
#        [25.841108],
#        [25.879072],
#        [25.96464 ],
#        [26.098879],
#        [26.240402],
#        [26.384066],
#        [26.522697],
#        [26.645185],
#        [26.745218],
#        [26.81849 ],
#        [26.87476 ],
#        [26.920345],
#        [26.960747],
#        [26.996574],
#        [27.022554],
#        [27.039093],
#        [27.052254],
#        [27.067923],
#        [27.079042],
#        [27.07107 ],
#        [27.037165],
#        [26.980247],
#        [26.90974 ],
#        [26.820976],
#        [26.71784 ],
#        [26.617151],
#        [26.53589 ],
#        [26.470314],
#        [26.410204],
#        [26.361803],
#        [26.32093 ],
#        [26.28097 ],
#        [26.243097],
#        [26.203796],
#        [26.161522],
#        [26.11589 ],
#        [26.096088],
#        [26.113699],
#        [26.163143],
#        [26.23857 ],
#        [26.337557],
#        [26.448366],
#        [26.578604],
#        [26.716358],
#        [26.85553 ],
#        [26.995653],
#        [27.143229],
#        [27.296183],
#        [27.437738],
#        [27.561735],
#        [27.663057],
#        [27.760004],
#        [27.874891],
#        [28.02699 ],
#        [28.20905 ],
#        [28.40674 ],
#        [28.617905],
#        [28.833233],
#        [29.044357],
#        [29.238441],
#        [29.42374 ],
#        [29.585835],
#        [29.723309],
#        [29.82863 ],
#        [29.90421 ],
#        [29.945295],
#        [29.955227],
#        [29.937943],
#        [29.905115],
#        [29.862814],
#        [29.809662],
#        [29.748547],
#        [29.670265],
#        [29.566526],
#        [29.455002],
#        [29.349052],
#        [29.246817],
#        [29.165596],
#        [29.122818],
#        [29.122475],
#        [29.155407],
#        [29.210796],
#        [29.269373],
#        [29.318972],
#        [29.350386],
#        [29.353502],
#        [29.31278 ],
#        [29.231895],
#        [29.115984],
#        [28.959381],
#        [28.77549 ],
#        [28.57303 ],
#        [28.364525],
#        [28.15046 ],
#        [27.92575 ],
#        [27.697126],
#        [27.485746],
#        [27.296011],
#        [27.134592],
#        [27.010246],
#        [26.920183],
#        [26.85113 ],
#        [26.787891],
#        [26.74794 ],
#        [26.72837 ],
#        [26.71799 ],
#        [26.713076],
#        [26.724943],
#        [26.750406],
#        [26.793304],
#        [26.848612],
#        [26.90513 ],
#        [26.959463],
#        [27.000126],
#        [27.023884],
#        [27.034836],
#        [27.029161],
#        [27.013922],
#        [26.99027 ],
#        [26.96698 ],
#        [26.952099],
#        [26.956778],
#        [26.981792],
#        [27.02007 ],
#        [27.06277 ],
#        [27.100634],
#        [27.130484],
#        [27.163883]], dtype=float32)

# %%
plot_predictions(test_set, predict_stock_price)

# %% [markdown]
# #### 基于GRU 预测

# %%
model_gru = Sequential()
model_gru .add(GRU(50, return_sequences = True,input_shape = (x_train.shape[1], 1), activation='tanh'))

# %%
model_gru.add(Dropout(0.2))
model_gru.add(GRU(50, activation='tanh'))

# %%
model_gru.add(Dropout(0.2))

# %%
model_gru.add(Dense(1))

# %%
# 编译
model_gru.compile(optimizer=SGD(lr=0.01,decay=1e-7,momentum=0.9),loss='mse')

# %%
#训练
history = model_gru.fit(x_train, y_train, epochs = 40, batch_size = 72)
# Out:
# Epoch 1/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0971
# Epoch 2/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0161
# Epoch 3/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0057
# Epoch 4/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0043
# Epoch 5/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0037
# Epoch 6/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0035
# Epoch 7/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0035
# Epoch 8/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0031
# Epoch 9/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0029
# Epoch 10/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0028
# Epoch 11/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0026
# Epoch 12/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0027
# Epoch 13/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0027
# Epoch 14/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0025
# Epoch 15/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0023
# Epoch 16/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0025
# Epoch 17/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0025
# Epoch 18/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0025
# Epoch 19/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0021
# Epoch 20/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0023
# Epoch 21/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0021
# Epoch 22/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0023
# Epoch 23/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0021
# Epoch 24/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0021
# Epoch 25/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0019
# Epoch 26/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0021
# Epoch 27/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0021
# Epoch 28/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0020
# Epoch 29/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0018
# Epoch 30/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0019
# Epoch 31/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 32/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 33/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0019
# Epoch 34/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0016
# Epoch 35/40
# 1427/1427 [==============================] - 1s 1ms/step - loss: 0.0018
# Epoch 36/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0017
# Epoch 37/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0018
# Epoch 38/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0018
# Epoch 39/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0017
# Epoch 40/40
# 1427/1427 [==============================] - 2s 1ms/step - loss: 0.0017

# %%
# 准备测试集进行预测
x_test = []
for i in range(60 , 566):
    x_test.append(inputs[i-60:i,0])
    
x_test=np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
GRU_predicted = model_gru.predict(x_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted)

# %%
#可视化
plot_predictions(test_set,GRU_predicted_stock_price)

# %%
plt.plot(history.history['loss'],label='sss')
plt.legend()
plt.show()
